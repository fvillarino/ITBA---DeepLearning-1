# %%
import numpy as np

# %%
array_1 = np.array([1,2,3,4])
array_2 = np.array([3,2,1,6])

# %%
# Dimensión del array
array_1.shape
# Out:
# (4,)

# %%
matriz_1 = np.array([
    [1,2,3,4],
    [3,5,2,3]
])

# %%
matriz_1
# Out:
# array([[1, 2, 3, 4],
#        [3, 5, 2, 3]])

# %%
matriz_1.shape
# Out:
# (2, 4)

# %%
from matplotlib import pyplot as plt

# %%
X = np.random.normal(0,1,200)
Y = np.random.normal(0,1,200)

# %%
plt.scatter(X,Y)

# %%
plt.scatter(array_1,array_2)

# %%
t = np.linspace(0,10,100)
x1 = t**2

# %%
plt.plot(t,x1)

# %%
# Histograma

plt.hist(X, bins=50)
# Out:
# (array([ 1.,  0.,  0.,  0.,  0.,  0.,  0.,  1.,  1.,  2.,  3.,  3.,  2.,
#          1.,  6.,  2.,  8.,  2.,  9.,  9.,  5.,  7., 12., 10.,  9., 13.,
#          5.,  9.,  9.,  5.,  5.,  5.,  2.,  7.,  5.,  5.,  8.,  4.,  4.,
#          4.,  2.,  3.,  3.,  4.,  2.,  2.,  0.,  0.,  0.,  1.]),
#  array([-3.138636  , -3.01625879, -2.89388159, -2.77150438, -2.64912717,
#         -2.52674997, -2.40437276, -2.28199555, -2.15961835, -2.03724114,
#         -1.91486393, -1.79248673, -1.67010952, -1.54773231, -1.42535511,
#         -1.3029779 , -1.18060069, -1.05822349, -0.93584628, -0.81346907,
#         -0.69109187, -0.56871466, -0.44633745, -0.32396025, -0.20158304,
#         -0.07920583,  0.04317137,  0.16554858,  0.28792579,  0.41030299,
#          0.5326802 ,  0.65505741,  0.77743461,  0.89981182,  1.02218903,
#          1.14456623,  1.26694344,  1.38932065,  1.51169785,  1.63407506,
#          1.75645227,  1.87882947,  2.00120668,  2.12358389,  2.24596109,
# ...

# %%
X1 = X[:10]

# %%
X1
# Out:
# array([10.        , -0.14835956, -0.0778707 ,  1.10596267, -1.06988548,
#        -0.88558708,  0.40743853, -2.164163  ,  0.54257393, -0.2599376 ])

# %%
# Out:
# array([ 1.00000000e+01, -1.48359558e-01, -7.78706962e-02,  1.10596267e+00,
#        -1.06988548e+00, -8.85587076e-01,  4.07438526e-01, -2.16416300e+00,
#         5.42573928e-01, -2.59937599e-01,  9.31549935e-01,  5.69046566e-03,
#         2.18512881e-01, -8.47718654e-01,  2.01267253e-01,  9.30191548e-01,
#        -1.30502304e+00, -1.96965481e-01, -5.08083974e-01,  6.79966252e-01,
#         1.78301668e-03, -1.38689559e+00,  9.62658931e-01,  1.00760303e+00,
#         2.33876598e+00,  3.03209742e-01, -1.72936506e+00, -2.21757124e-01,
#         1.34001124e+00, -6.80547191e-01,  4.33707746e-01, -8.15399389e-01,
#        -7.21242801e-01,  1.25024055e+00,  1.48645845e+00,  1.26939633e-01,
#        -1.22691219e+00, -7.65433112e-01,  1.19910852e+00, -9.83623583e-01,
#        -1.38855303e+00, -4.02580175e-01,  4.47523754e-01, -1.67568717e-01,
#         2.43407603e+00,  2.98022433e+00, -4.30796283e-01, -1.71139722e+00,
# ...

# %%
X[0]=10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-194939105b38> in <module>
# ----> 1 X[0]=10
#
# NameError: name 'X' is not defined

# %% [markdown]
# # Matrices

# %%
M1 = np.array([[2,4],[5,6]])
M2 = np.matrix([[1,3],[2,8]])

# %%
M1
# Out:
# array([[2, 4],
#        [5, 6]])

# %%
M2
# Out:
# matrix([[1, 3],
#         [2, 8]])

# %%
M1*M2
# Out:
# matrix([[10, 38],
#         [17, 63]])

# %%
M1+M2
# Out:
# matrix([[ 3,  7],
#         [ 7, 14]])

# %%
2*M1
# Out:
# array([[ 4,  8],
#        [10, 12]])

# %%
-1*M1
# Out:
# array([[-2, -4],
#        [-5, -6]])

# %%
M3 = np.array([[1],[2],[4],[6]]) # M3 4x1
print(M3.shape)
M4 = np.array([1,2,-1,5])        # M4 1x4
print(M4.shape)
M5 = M3*M4 # M5 4x4
print(M5.shape)
# Out:
# (4, 1)
# (4,)
# (4, 4)

# %%
M3
# Out:
# array([[1],
#        [2],
#        [4],
#        [6]])

# %%
M4
# Out:
# array([ 1,  2, -1,  5])

# %%
M3*M4
# Out:
# array([[ 1,  2, -1,  5],
#        [ 2,  4, -2, 10],
#        [ 4,  8, -4, 20],
#        [ 6, 12, -6, 30]])

# %%
M3.T
# Out:
# array([[1, 2, 4, 6]])

# %%
P = np.array([[3,1],[2,1]])
Pin = np.array([[1,-1],[-2,3]])
F = np.array([[3,1],[2,1]])
I = np.array([[1,0],[0,1]])

# %%
P*P
# Out:
# array([[9, 1],
#        [4, 1]])

# %%
2*P
# Out:
# array([[6, 2],
#        [4, 2]])

# %%
P+P
# Out:
# array([[6, 2],
#        [4, 2]])

# %%
P*F
# Out:
# array([[9, 1],
#        [4, 1]])

# %%
P**2
# Out:
# array([[9, 1],
#        [4, 1]])

# %%
P*Pin
# Out:
# array([[ 3, -1],
#        [-4,  3]])

# %% [markdown]
# # Matplotlib

# %%
from matplotlib import pyplot as plt

# %%
x = [1,4,6]
y = [2,5,7]
x2 = [1,3,5,1,3]
y2 = [1,2,3,5,2]
plt.xlabel('X')
plt.ylabel('Y')
plt.axis([0, 7, 0, 7])
plt.title('Gráfico')
plt.plot(x,y, label='Blue line')
plt.plot(x2,y2,'ro', label='Other line')
plt.legend()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])
# Out:
# (0.0, 6.0, 0.0, 20.0)

# %%
x=np.arange(0,5,1)
y=x**2
y1=x**3
y2=1/x
plt.xlabel('X')
plt.ylabel('Y')
plt.plot(x,y,x,y1,x,y2)
# Out:
# <ipython-input-91-dd5eda088c73>:4: RuntimeWarning: divide by zero encountered in true_divide
#   y2=1/x
# ...
